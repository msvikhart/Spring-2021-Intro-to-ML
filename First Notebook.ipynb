# %%
print('Hello World')
# Out:
# Hello World

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0,2*3.14159265,100)
print(x)
y = np.cos(x)
z = np.sin(x - 3.14159265)
t = x**.5
plt.plot(x, y)
plt.plot(x, z)
plt.plot(x, t)
# Out:
# [0.         0.06346652 0.12693304 0.19039955 0.25386607 0.31733259
#  0.38079911 0.44426563 0.50773215 0.57119866 0.63466518 0.6981317
#  0.76159822 0.82506474 0.88853125 0.95199777 1.01546429 1.07893081
#  1.14239733 1.20586385 1.26933036 1.33279688 1.3962634  1.45972992
#  1.52319644 1.58666295 1.65012947 1.71359599 1.77706251 1.84052903
#  1.90399555 1.96746206 2.03092858 2.0943951  2.15786162 2.22132814
#  2.28479465 2.34826117 2.41172769 2.47519421 2.53866073 2.60212725
#  2.66559376 2.72906028 2.7925268  2.85599332 2.91945984 2.98292635
#  3.04639287 3.10985939 3.17332591 3.23679243 3.30025895 3.36372546
#  3.42719198 3.4906585  3.55412502 3.61759154 3.68105805 3.74452457
#  3.80799109 3.87145761 3.93492413 3.99839065 4.06185716 4.12532368
#  4.1887902  4.25225672 4.31572324 4.37918975 4.44265627 4.50612279
#  4.56958931 4.63305583 4.69652235 4.75998886 4.82345538 4.8869219
#  4.95038842 5.01385494 5.07732145 5.14078797 5.20425449 5.26772101
# ...
